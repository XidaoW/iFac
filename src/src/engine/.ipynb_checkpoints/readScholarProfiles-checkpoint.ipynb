# %%
from pyspark import SparkConf
from pyspark.sql import SparkSession

import sys
conf = SparkConf()
conf.set("spark.driver.memory", "100g")
conf.set("spark.executor.memory", "100g")
conf.set("spark.master", "local[30]")
conf.set("spark.driver.maxResultSize", "100g")
conf.set("spark.executor.heartbeatInterval","1000000000s")
conf.set("spark.network.timeout","1000000000s")
spark = SparkSession.builder.config(conf=conf).appName("convertProfile").getOrCreate()

from pyspark.ml.feature import HashingTF, IDF, Tokenizer
from pyspark.ml.feature import Tokenizer, RegexTokenizer, CountVectorizer
from pyspark.sql.functions import col, udf
from pyspark.sql.types import IntegerType
from pyspark.ml.feature import StopWordsRemover


from pyspark.sql import functions as F
from pyspark.sql import types as T
from pyspark.ml.linalg import SparseVector, DenseVector
from pyspark.sql.types import *
from pyspark.sql.functions import lit, col, regexp_replace
from pyspark.sql.functions import split, explode




from pyspark.ml.feature import HashingTF, IDF, Tokenizer
from pyspark.ml.feature import Tokenizer, RegexTokenizer, CountVectorizer
from pyspark.sql.functions import col, udf
from pyspark.sql.types import IntegerType


from pyspark.sql import functions as F
from pyspark.sql import types as T
from pyspark.ml.linalg import SparseVector, DenseVector
from pyspark.sql.types import *
from pyspark.sql.functions import lit, col, regexp_replace
from pyspark.sql.functions import split, explode

# %%
class PokeProfile():
    def __init__(self):
        """
        data can be downloaded at http://snap.stanford.edu/data/soc-Pokec.html
        or run:
        wget http://snap.stanford.edu/data/soc-pokec-relationships.txt.gz .
        wget http://snap.stanford.edu/data/soc-pokec-profiles.txt.gz .
        zcat soc-pokec-relationships.txt.gz > soc-pokec-relationships.txt
        zcat soc-pokec-profiles.txt.gz > soc-pokec-profiles.txt                        
        mkdir output # place to save output parquet
        mkdir vocabulary # place to save vocabulary (vector-word mapping)
        """
        self.userFile = "data/seminar_year.csv"
        
    def readProfile(self):
        """
        read the profile data
        """
        self.profiles_=spark.read.option("delimiter", ",").csv(self.userFile)
        self.profiles_ = self.profiles_.na.fill("")
        

    def formatHeaders(self, headers = [ "user_id","year","title"]):
        """
        provide the headers of the data frame
        """
        for c,n in zip(self.profiles_.columns,headers):
            self.profiles_ = self.profiles_.withColumnRenamed(c,n)        
            
    def tokenize(self, inputColProfile = "I_am_working_in_field", vocSize = 40, minDF = 1.0):
        """
        tokenize string column, count the occurence of words and then use the occurence of the top words as vector
        :type inputColProfile: str: column to extract the vector
        :type vocSize: int: number of words to count
        :type minDF: float: minimun document frequency of the word            
        :rtype: None

        """
        self.vocSize = vocSize        
        self.minDF = minDF
        self.inputColProfile = inputColProfile
        self.outputColProfile = "{}_words".format(self.inputColProfile)
        self.outputColProfileStop = "{}_words_stp".format(self.inputColProfile)        
        self.outputTokensColProfile = "{}_tokens".format(self.inputColProfile)
        self.outputTokensDenseColProfile = "{}_dense".format(self.inputColProfile)

        regexTokenizer = RegexTokenizer(inputCol=self.inputColProfile, outputCol=self.outputColProfile, pattern="\\W|\\d")
        self.profiles_ = regexTokenizer.transform(self.profiles_)

        remover = StopWordsRemover(inputCol=self.outputColProfile, outputCol=self.outputColProfileStop)
        self.profiles_ = remover.transform(self.profiles_)

        self.cv = CountVectorizer(inputCol=self.outputColProfileStop, 
                             outputCol=self.outputTokensColProfile, 
                             vocabSize=self.vocSize, minDF=self.minDF)
        try:
            self.model = self.cv.fit(self.profiles_)        
            self.profiles_ = self.model.transform(self.profiles_)        
            vector_udf = udf(lambda vector: vector.toArray().tolist(),ArrayType(DoubleType()))

            self.profiles_ = self.profiles_.withColumn(self.outputTokensDenseColProfile, vector_udf(self.outputTokensColProfile))
            self.profiles_ = self.profiles_.drop(self.inputColProfile)
            self.profiles_ = self.profiles_.drop(self.outputColProfile)
            self.profiles_ = self.profiles_.drop(self.outputColProfileStop)            
            self.profiles_ = self.profiles_.drop(self.outputTokensColProfile)
        except:
            print("Tokenizing {} Failed".format(self.inputColProfile))
            self.profiles_ = self.profiles_.drop(self.outputColProfile)
            
    def flattenVectorColumns(self):
        """
        convert from 
            col1=[0,1,2], col2=[0,1,2], col3=3, col4=0
            to
            col1.0,col1.1,col1.2,col2.0, col2.1,col2.2, col3, col4
        """
        stringColumns = self.listStringColumns(self.index, self.cnt_each)        
        stringColumns = [column + "_dense" for column in stringColumns]
        self.newColumns = [self.profiles_[column][i] for column in stringColumns for i in range(self.vocSize)]
        self.nonstringColumns = [column for column in self.profiles_.columns if column not in stringColumns]
        self.profiles_flatten = self.profiles_.select(["user_id", "year"] + self.newColumns)
#         self.profiles_flatten = self.profiles_.select(self.nonstringColumns + self.newColumns)        
#         self.profiles_flatten = self.profiles_flatten.drop("_c59")

    def saveVocabulary(self):
        """
        save the vocabulary to a separate file; 
        vocabulary can work as a look up table for the word given the index in the word vector        
        """
        import pandas as pd
        pd.DataFrame(self.model.vocabulary).to_csv("data/vocabulary/{}.txt".format(self.inputColProfile), 
                                                   sep='\t', encoding='utf-8', header=False)
        
    def listStringColumns(self, index = 0, cnt_each = 10):
        """
        list of string columns in the data
        """
        self.index = index
        self.cnt_each = cnt_each
        # "pets", "completed_level_of_education", ""
        all_columns = ["title"]
        self.cnt_string = len(all_columns) 
        start, end = index*cnt_each, (index+1)*cnt_each
        return all_columns[start:end]
    

    def saveOutput(self, data, outputfile = "soc-pokec-profiles-vector", save_format = "parquet"):
        """
        save data as parquet
        """
        if save_format == "parquet":
            data.repartition(1).write.parquet("{}.parquet".format(outputfile))
        else:
            data.repartition(1).write.csv("{}.csv".format(outputfile))

from pyspark.sql.functions import array, col, explode, struct, lit

df = sc.parallelize([(1, 0.0, 0.6), (1, 0.6, 0.7)]).toDF(["A", "col_1", "col_2"])

def to_long(df, by):

    # Filter dtypes and split into column names and type description
    cols, dtypes = zip(*((c, t) for (c, t) in df.dtypes if c not in by))
    # Spark SQL supports only homogeneous columns
    assert len(set(dtypes)) == 1, "All columns have to be of the same type"

    # Create and explode an array of (column_name, column_value) structs
    kvs = explode(array([
      struct(lit(c).alias("key"), col(c).alias("val")) for c in cols
    ])).alias("kvs")

    return df.select(by + [kvs]).select(by + ["kvs.key", "kvs.val"])

# %%
PP = PokeProfile()
PP.readProfile()
PP.formatHeaders()

# %%
for i in range(1):
    print(i)
    for eachColumn in PP.listStringColumns(i, cnt_each = 1):
        PP.tokenize(inputColProfile = eachColumn, vocSize = 40)
        PP.saveVocabulary()
        PP.flattenVectorColumns()

# %%
headers = ["user_id", "year"] + PP.model.vocabulary
for c,n in zip(PP.profiles_flatten.columns,headers):
    PP.profiles_flatten = PP.profiles_flatten.withColumnRenamed(c,n)

# %%
PP.profiles_flatten = to_long(PP.profiles_flatten, ["user_id", "year"])
PP.profiles_flatten = PP.profiles_flatten.repartition(1)
PP.profiles_flatten.write.csv("data/scholar_top_{}.csv".format(PP.vocSize), header = False, mode="overwrite")
# Out:
# [Row(user_id=u'Ang', year=u'2018', networks=0.0, social=0.0, anomaly=0.0, twitter=0.0, dynamic=0.0, academic=0.0, hypersphere=0.0, conferences=0.0, detection=0.0, mobile=0.0, analysis=0.0, media=0.0, modeling=0.0, information=0.0, event=0.0, sentiment=0.0, unsupervised=0.0, beyond=1.0, robust=0.0, process=0.0, scale=0.0, march=1.0, feet=1.0, embedding=0.0, effect=0.0, discovery=0.0, method=0.0, protests=1.0, visual=0.0, seeking=0.0, data=0.0, role=0.0, large=0.0, analytics=0.0, talking=1.0, events=0.0, time=0.0, streaming=0.0, deep=0.0, regression=0.0),
#  Row(user_id=u'Ang', year=u'2018', networks=0.0, social=0.0, anomaly=0.0, twitter=0.0, dynamic=0.0, academic=0.0, hypersphere=0.0, conferences=0.0, detection=0.0, mobile=0.0, analysis=0.0, media=0.0, modeling=0.0, information=0.0, event=0.0, sentiment=0.0, unsupervised=0.0, beyond=0.0, robust=0.0, process=0.0, scale=0.0, march=0.0, feet=0.0, embedding=0.0, effect=0.0, discovery=0.0, method=0.0, protests=0.0, visual=0.0, seeking=0.0, data=0.0, role=0.0, large=0.0, analytics=0.0, talking=0.0, events=1.0, time=0.0, streaming=0.0, deep=0.0, regression=0.0),
#  Row(user_id=u'Ang', year=u'2018', networks=0.0, social=0.0, anomaly=0.0, twitter=0.0, dynamic=0.0, academic=0.0, hypersphere=0.0, conferences=0.0, detection=0.0, mobile=0.0, analysis=1.0, media=0.0, modeling=0.0, information=0.0, event=0.0, sentiment=1.0, unsupervised=0.0, beyond=0.0, robust=0.0, process=0.0, scale=0.0, march=0.0, feet=0.0, embedding=0.0, effect=0.0, discovery=0.0, method=0.0, protests=0.0, visual=0.0, seeking=0.0, data=0.0, role=0.0, large=0.0, analytics=0.0, talking=0.0, events=0.0, time=0.0, streaming=0.0, deep=0.0, regression=0.0)]

# %%
# import pandas as pd
# self = PP
# picso = pd.read_csv("data/picso.csv", header=None)
# picso.columns = ['member', 'year', 'keyword', 'value']
# # policy_group = policy.groupby(self.column)['adoption'].sum()
# # policy_group1 = policy_group.unstack(fill_value=0).to_panel()
# # self.hist = policy_group1.fillna(0).values

# %%
shots = pd.read_csv("data/NBA_shots_201415.csv")
shots = shots[['PLAYER_ID','PLAYER_NAME','TEAM_ID','TEAM_NAME','ZoneName','PERIOD','SHOT_ATTEMPTED_FLAG','SHOT_MADE_FLAG']]
shots.PERIOD[shots.PERIOD > 4] = 5

# %%
shots.iloc[1:4]
# Out:
#    PLAYER_ID PLAYER_NAME     TEAM_ID        TEAM_NAME                ZoneName  \
# 1     203112  Quincy Acy  1610612752  New York Knicks            MidrangeSlot
# 2     203112  Quincy Acy  1610612752  New York Knicks               LeftWing2
# 3     203112  Quincy Acy  1610612752  New York Knicks  Mid-Range!Left Side(L)
#
#    PERIOD  SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG
# 1       1                    1               0
# 2       4                    1               1
# 3       4                    1               0

# %%
self.column = ['PERIOD','PLAYER_NAME','ZoneName']

shots_total = shots.groupby(['PLAYER_NAME'])['SHOT_ATTEMPTED_FLAG'].sum()
top_players = list(shots_total.sort_values(ascending=False).iloc[:15].index)

shots = shots[shots.PLAYER_NAME.isin(top_players)]
shots_group_data_attempted = shots.groupby(self.column)['SHOT_ATTEMPTED_FLAG'].sum()
shots_group_data_made = shots.groupby(self.column)['SHOT_MADE_FLAG'].sum()
shots_group_data_attempted = shots_group_data_made.div(shots_group_data_attempted, level=0)
shots_group_data_attempted1 = shots_group_data_attempted.unstack(fill_value=0).to_panel()
self.hist = shots_group_data_attempted1.fillna(0).values

# %%
# Out:
#         PLAYER_ID        PLAYER_NAME     TEAM_ID               TEAM_NAME  \
# 2244       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2245       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2246       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2247       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2248       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2249       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2250       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2251       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2252       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2253       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2254       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2255       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2256       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2257       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2258       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2259       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2260       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2261       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2262       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2263       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2264       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2265       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2266       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2267       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2268       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2269       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2270       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2271       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2272       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# 2273       200746  LaMarcus Aldridge  1610612757  Portland Trail Blazers
# ...           ...                ...         ...                     ...
# 170444     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170445     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170446     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170447     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170448     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170449     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170450     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170451     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170452     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170453     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170454     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170455     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170456     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170457     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170458     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170459     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170460     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170461     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170462     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170463     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170464     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170465     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170466     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170467     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170468     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170469     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170470     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170471     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170472     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
# 170473     201566  Russell Westbrook  1610612760   Oklahoma City Thunder
#
#                       ZoneName  PERIOD  SHOT_ATTEMPTED_FLAG  SHOT_MADE_FLAG
# 2244                 LeftWing3       1                    1               1
# 2245    Mid-Range!Left Side(L)       1                    1               0
# 2246                Deep Paint       1                    1               1
# 2247                 LeftWing2       1                    1               0
# 2248    Mid-Range!Left Side(L)       1                    1               1
# 2249    Mid-Range!Left Side(L)       1                    1               1
# 2250                 LeftWing2       1                    1               1
# 2251    Mid-Range!Left Side(L)       1                    1               1
# 2252                BasketArea       2                    1               1
# 2253                RightWing2       2                    1               0
# 2254                BasketArea       3                    1               0
# 2255                 LeftWing2       3                    1               1
# 2256    Mid-Range!Left Side(L)       3                    1               0
# 2257                Deep Paint       4                    1               0
# 2258                BasketArea       4                    1               0
# 2259                Deep Paint       4                    1               0
# 2260                Deep Paint       4                    1               1
# 2261                 LeftWing2       4                    1               1
# 2262              MidrangeSlot       4                    1               0
# 2263              MidrangeSlot       1                    1               1
# 2264              MidrangeSlot       1                    1               0
# 2265                 LeftWing3       1                    1               0
# 2266    Mid-Range!Left Side(L)       1                    1               0
# 2267              MidrangeSlot       1                    1               0
# 2268             RightBaseline       1                    1               1
# 2269    Mid-Range!Left Side(L)       1                    1               1
# 2270                Deep Paint       1                    1               1
# 2271    Mid-Range!Left Side(L)       2                    1               1
# 2272    Mid-Range!Left Side(L)       3                    1               0
# 2273    Mid-Range!Left Side(L)       3                    1               0
# ...                        ...     ...                  ...             ...
# 170444  Mid-Range!Left Side(L)       3                    1               1
# 170445              BasketArea       3                    1               1
# 170446              Deep Paint       3                    1               1
# 170447              RightWing3       3                    1               0
# 170448  Mid-Range!Left Side(L)       3                    1               0
# 170449              BasketArea       4                    1               0
# 170450              Deep Paint       4                    1               0
# 170451              Deep Paint       4                    1               1
# 170452                TopOfArc       4                    1               0
# 170453              BasketArea       4                    1               0
# 170454              Deep Paint       1                    1               0
# 170455                TopOfArc       1                    1               1
# 170456              Deep Paint       1                    1               1
# 170457              Deep Paint       1                    1               1
# 170458              RightWing2       1                    1               1
# 170459              Deep Paint       1                    1               1
# 170460              Deep Paint       1                    1               1
# 170461                TopOfArc       1                    1               1
# 170462              BasketArea       2                    1               0
# 170463  Mid-Range!Left Side(L)       2                    1               0
# 170464              Deep Paint       2                    1               1
# 170465              RightWing2       2                    1               1
# 170466              BasketArea       2                    1               1
# 170467               LeftWing3       2                    1               0
# 170468  Mid-Range!Left Side(L)       2                    1               1
# 170469               LeftWing3       2                    1               0
# 170470               LeftWing2       3                    1               0
# 170471                TopOfArc       3                    1               0
# 170472               LeftWing2       3                    1               0
# 170473              Deep Paint       3                    1               0
#
# [19282 rows x 8 columns]

# %%
top_players = list(shots_total.sort_values(ascending=False).iloc[:15].index)

# %%
# Out:
# PERIOD  PLAYER_NAME      ZoneName
# 1       Aaron Brooks     Backcourt!Back Court(BC)    0.000000
#                          BasketArea                  0.500000
#                          Deep Paint                  0.522727
#                          LeftCorner                  0.000000
#                          LeftWing2                   0.250000
#                          LeftWing3                   0.250000
#                          Mid-Range!Left Side(L)      0.444444
#                          MidrangeSlot                0.666667
#                          RightBaseline               0.300000
#                          RightCorner3                0.600000
#                          RightWing2                  0.000000
#                          RightWing3                  0.450000
#                          TopOfArc                    0.307692
#         Aaron Gordon     Backcourt!Back Court(BC)    0.000000
#                          BasketArea                  0.166667
#                          Deep Paint                  0.714286
#                          LeftCorner                  0.250000
#                          LeftWing3                   0.000000
#                          Mid-Range!Left Side(L)      0.000000
#                          MidrangeSlot                0.000000
#                          RightCorner3                0.666667
#                          RightWing3                  0.000000
#                          TopOfArc                    1.000000
#         Adreian Payne    BasketArea                  0.450000
#                          Deep Paint                  0.590909
#                          LeftWing2                   0.200000
#                          LeftWing3                   0.000000
#                          Mid-Range!Left Side(L)      0.166667
#                          MidrangeSlot                0.285714
#                          RightBaseline               0.250000
#                                                        ...
# 5       Wesley Johnson   Mid-Range!Left Side(L)      1.000000
#                          TopOfArc                    0.000000
#         Wesley Matthews  BasketArea                  1.000000
#                          Deep Paint                  0.000000
#                          LeftCorner                  0.000000
#                          LeftWing3                   0.500000
#                          MidrangeSlot                1.000000
#                          RightCorner3                1.000000
#                          RightWing3                  0.000000
#                          TopOfArc                    0.000000
#         Will Barton      LeftWing3                   0.500000
#                          RightWing3                  0.000000
#         Wilson Chandler  BasketArea                  0.000000
#                          Deep Paint                  0.250000
#                          LeftCorner                  0.000000
#                          LeftWing3                   0.333333
#                          RightCorner3                1.000000
#                          RightWing3                  0.333333
#                          TopOfArc                    0.000000
#         Zach LaVine      Deep Paint                  0.500000
#                          LeftCorner                  0.000000
#                          LeftWing3                   0.000000
#                          RightWing2                  0.000000
#         Zach Randolph    BasketArea                  1.000000
#                          Deep Paint                  0.600000
#                          Mid-Range!Left Side(L)      0.000000
#                          RightBaseline               1.000000
#         Zaza Pachulia    BasketArea                  1.000000
#                          Deep Paint                  0.000000
#                          MidrangeSlot                0.000000
# dtype: float64

# %%
self.column = ['PERIOD','PLAYER_NAME','ZoneName']
shots_group_data_attempted = shots.groupby(self.column)['SHOT_ATTEMPTED_FLAG'].sum()
